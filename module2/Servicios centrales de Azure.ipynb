# %% [markdown]
# # Servicios centrales de Azure
#
#
#
# ## 1. Exploracion de los servicios de Azure Compute
#
# ### 1.1 Introduccion
# * Azure Virtual Machines
# * Azure App Service
# * Azure Container Instances
# * Azure Kubernetes Service
# * Azure Functions
# * Azure Virtual Desktop
#
# ### 1.1 Introduccion a los servicios de Azure Compute
#
# Algunos de los servicios mas demandados son:
#
# **Azure Virtual Machines** Emular equipos fisicos  con memorial, almacenamiento, y recursos red con SO. Son infraestructura como servicio (IaaS)
#
# **Azure Container Instances** ADminsitrar máquinas virtuales idénticas. Facilidad para compilar servicios para contenedores, macroprocesos y macrodatos.
#
# **Containers y Kubernetes**  Son entornos de aplicacion ligeros y virtualizados. Escalan horizontalmente, se detienen de forma dinamica y rapida.
#
# **App service** compilar, implementar y escalar API's movile y web. Es plataforma como servicio (PaaS).
#
# **Funciones** Pa desarrolladores, fuck infrastructure y paltaforma. Just code. Se usan para solicutudes REST, con temporizador porque es rapido.
#
#
# ### 1.2 Decisión de cuándo usar Azure Virtual Machines
#
# CUando usarlas?
#
# * Control del SO.
# * Personalizar software.
# * Usar configuraciones de hospedaje personalizadas
# * Pruebas de desarrollo. Eliminarlas despues
# * Ejecutar aplicaciones en la nube. Pa' ahorrarse infrsatetuccra
# * HOra extender centro de recursos nube
# * Recueraciond e desatre. Con IaaS
#
# Si confugirar, actualizar y mantener el software. Como? Pues asi:
#
#
#
# ###### Traslado a la nube con amquinas virtuales
# Migrar de fisico a nube (Lift and shift). Crear imagne del servidor fisico, y hospedar con pocos o ningun cambio.
#
# ###### Escalado de máquinas virtuales en Azure
# Agrupar maquinas pa' altadispobilidad, esalabilidad y redundancia. Como?
#
# **Conjuntos de escalado de máquinas virtuales** Crear y adminsitrar  grupo e maquinas virtuales, con carga equilibrada.
# ** Azure Batch**  informática de alto rendimiento (HPC)
#     *Iniciará un grupo de máquinas virtuales de proceso de forma automática.
#     *Instalará aplicaciones y datos de almacenamiento provisional.
# Ejecutará trabajos con tantas tareas como tenga.
# Identificará errores.
# Reordenará la cola de trabajo.
# Reducirá verticalmente el grupo a medida que se complete el trabajo.
#
#
# ### 1.3 Decisión de cuándo usar Azure App Service
# Que puedo hospedar:
# * Aplicaciones web Azure App Service.
#     * Lenguajes aceptados: ASP.NET, ASP.NET Core, Java, Ruby, Node.js, PHP o Python
#     * OS: Linux, WIndows
# * PAplicaciones de API
#      * COmpatibilidad API web basadas en REST: COn Swagger. Se empaqueta y publica en Azure Marquet Place. Para consumirse desde cualquier HTTP y HTTPS
# * Trabajos web
#      * Se usan apra ejecutar tareas en segundo plano
#     * WebJobs para ejecutar programa (.exe, Java, PHP, Python o Node.js) o un script (.cmd, .bat, PowerShell o Bash)
# * Aplicaciones móviles
#     * COmpilar el back end para IOS y Android
#         * Almacenar datos SQL en la nube.
#         * Autenticar a clientes con proveedores sociales comunes, como MSA, Google, Twitter y Facebook.
#         * Enviar notificaciones de inserción.
#         * Ejecutar lógica de back-end personalizada en C# o Node.js.
#     * Se puede automatizar desde Github, Azure DevOps y cualquiqer repositorio Git para CI
#
# Compatibilidad con el SDK para aplicaciones nativas de iOS y Android, Xamarin y React.
#
# Es plataforma como servicio (PaaS) , y me puedo conecntrar en el sitio web y API sin encargarme d ela infrestructura
#
# ###### Tipos de servicios de aplicaciones
#
# Ventajas:
# * Integrar implementación y administración
# * Proteger puntos de conexion
# * Escalar rápida durante alto trafico
# * alta disponibilidad por equilibrio de carga integrado y el administrador de tráfico
#
# ### 1.4 Decisión de cuándo usar Azure Container Instances o Azure Kubernetes Service
# Varias isntancias de uan aplicacion en un equipo con solo un SO
#
# ###### ¿Qué son los contenedores?
# Los contenedores son un entorno de virtualización. A diferencia de las máquinas virtuales, no se administra el sistema operativo de un contenedor. Disenados para crearse, escalarse horizontalmente y detenerse de forma dinámica, eficientes a los cambios de peticiones, reinician rapido ante bloqueos o interrupcion del hardware'
#
# ###### Comparación de máquinas virtuales con contenedores
# * **Virtual machines**
#     * Pros *
#         * Abstraccion CPU, Memory and storage
#         * Virtualiza harward
#         * Controlo OS
#     * Contras *
#         * Solo permite 1 OS al tiempo
#         * Slow
#
# * **COntainers**
#     * Pros *
#         * Abstraccion app
#         * Virtualiza OS
#         * Mas eficientes
#         * Smaller size
#         * Cluster orchestration
#         * POrtaiblidad y performance*
#     * Contras *
#         * Solo permite 1 OS al tiempo
#         * Slow
#
# Contiene una single app y sus dependencias y la deploy en el container host. El container host emula un run time environment que omite el OS e infrdestructura.
# Puedo tener muchas aplicaciones porque puedo tener muchos containers
#
# ###### Administrar contenedores
# * **Oorquestador de contenedores**.  iniciar, detener y escalar horizontalmente las instancias de la aplicación, según sea necesario.
# La tarea de automatizar y administrar una gran cantidad de contenedores (y de interactuar con ellos) se conoce como orquestación.
#
# Se administran con:
# * **Azure Container Instances**
#     * Rapido
#     * Es una oferta de plataforma como servicio (PaaS)
# * **Azure Kubernetes Service**
#     * Servicio para orquestrar contenedores
#
# ###### Que es kubernates
# Admistrador de cargas de trabajo en los contenedores. Combina la utomatizacion de la adminsitracion de conteneroes con APIS. Para crear centros de administracion nativas en la nube.
#
# * Adminsitra ubicacion de pods (con 1 o varios contenedores)
#     * Pods pueden ser escalados segun demanda
#     * Si se loquea
#     * Si se dana mueve uno que si funcione
#     * Horizontal grow
#     * Volver version anterior
#     * Islar la red
#     * SaaS services
#
# ###### Uso de contenedores en las soluciones
# Arquitectura de microservicios.  Esta arquitectura es donde se dividen las soluciones en partes más pequeñas e independientes.Por ejemplo, se puede dividir un sitio web en un contenedor que hospeda el front-end, otro que hospeda el back-end y un tercero para el almacenamiento. De esta forma, puede separar partes de la aplicación en secciones lógicas que se pueden mantener, escalar o actualizar independientemente.
#
# - Imagine que el back-end de su sitio web ha alcanzado el límite de su capacidad, pero el front-end y el almacenamiento no están sobrecargados. Podría:
#
#     * Escalar el back-end por separado para mejorar el rendimiento.
#     * Decidir utilizar un servicio de almacenamiento diferente.
#     * Reemplazar el contenedor de almacenamiento sin que ello afecte al resto de la aplicación.
#
# ###### Que es kmicroservicios
# * Web service , flexible.
# * Cada team puede Build, compile, test and deploy each service. Mejora la CI and faster realse
# * Como es mas pequenito es mas facil de mantener y entnder el codigo
# Bug manageme less risqky
# * Se cominican con API
# * Reducir interdependeni acuando se comunican a traves de orqustradores o mangment layer
#
#     * Cuando usarlo
#         * High relasea velocity
#         * High Scalable
#         * Muchos subdominios
#
#
# ### 1.5 Decisión de cuándo usar Azure Functions
# Que es una logica de functions? la aplicación espera una entrada determinada antes de realizar cualquier procesamiento.
#
# **Abstracción de servidores** Plataforma adminsitra automaticante servidores.
# **Escalado controlado por eventos** Como temporalizadores, HTTP (API y webhook), colas, entre otras
# **Microfacturacoin** Pago por el tiempo de ejecucion del codigo
#
# ###### Informática sin servidor en Azure
# 2 implmentacoines:
# **Azure Functions** Interes en codigo y no en infraestructura o plataforma subyacente.
# Con maquinas virtulaes me cobran aunque la maquina no este activa, aca no. Solo me cobran cuando la funcion desencadene un evento, un temproaliador o un mensaje a otro servicio.
#
# Las funciones peuden ser con o sin estado.
# * COn Estado (Durable funcions): Seguimiento actividad
# * Si estado (valor predeterminado).
# **Azure Logic App**
# Ejecutan flujos d etrabajo. DIsenados para autoamtizar escenarios mepresarailias y compliados a aprtir de bloques logicos.
# Empiezan con desencadenaro, activa con evento.
# Se crean mendiante disenador visual de Azure Portal o Visual Studio
#
# ###### IComparación entre Functions y Logic Apps
#
# Con Functions, se escribe código para completar cada paso.
# Con Logic Apps, se usa una GUI para definir las acciones y cómo se relacionan entre sí.
#
# ### 1.6 Decisión de cuándo usar Azure Virtual Desktop
# Pa que lso trabajadore remotos hagamos lo mismo con windows en al nube
#
# ### 1.6 Prueba de conocimiento
# 1. ¿Qué recurso de Azure Compute se puede implementar para administrar un conjunto de máquinas virtuales idénticas? **Conjuntos de escalado de máquinas virtuales**
# 2. ¿Cuál de los siguientes servicios deben usarse cuando la preocupación principal es realizar un trabajo en respuesta a un evento (a menudo a través de un comando REST) que necesita una respuesta en unos segundos?**Azure Functions**
# 3. La empresa tiene un equipo de trabajadores remotos que necesitan usar software basado en Windows para desarrollar las aplicaciones, pero los miembros del equipo usan diversos sistemas operativos, como macOS, Linux y Windows. ¿Qué servicio de Azure Compute le ayudaría a resolver este escenario?**Azure Virtual Desktop**
#
#
#
#
# ## 2.Exploración de los servicios de red de Azure
#
# ### 2.1 Introduccion
# * Recursos de red
# * Virtual Network, VPN Gateway y ExpressRoute
#
# ### 2.2 Aspectos básicos de Azure Virtual Network
# **Redes virtuales de Azure** Comica los recucros (VM, web apps, BD) entre si, los usuarios y los equipos clientes.
#
# * FUncionalidades:
#     * Aislamiento y segmentación
#     * Comunicación con Internet
#     * Comunicación entre recursos de Azure
#     * Comunicación con los recursos locales
#     * Enrutamiento del tráfico de red
#     * Filtrado del tráfico de red
#     * Conexión de redes virtuales
#
# ###### Configuración de red para las máquinas virtuales
# ###### IAislamiento y segmentación
# Se crea red virtual con direccion IP privada y publica(publico solo dentro de la red y no enrutable a internet).
# Tambine se peude configrar red virtual para usar servidor DNS
# ###### IComunicacion con internet
#
#
# ###### Prueba de conocimiento
# 1. Tailwind Traders desea crear un túnel de comunicación seguro entre sus sucursales. ¿Cuál de las siguientes tecnologías no se puede usar?
# **FTP implícito por SSL**
# 2. Tailwind Traders quiere usar Azure ExpressRoute para conectar su red local a la nube de Microsoft. ¿Cuál de las siguientes opciones no es un modelo de ExpressRoute que Tailwind Traders pueda usar?**Conexión Ethernet de punto a punto**
# 3. ¿Cuál de las siguientes opciones puede usar para vincular redes virtuales?**Emparejamiento de redes virtuales de Azure**
# 4. ¿Cuál de las siguientes opciones no es una de las ventajas de ExpressRoute?**Comunicación de red cifrada**
#
# ## 3. Exploración de los servicios de Azure Storage
#
# ### 3.1 Introduccion
# * Azure Blob Storage
# * Azure Disk Storage
# * Azure File Storage
# * Niveles de acceso de blob de Azure
# ### 3.2 Aspectos básicos de la cuenta de Azure Storage
# Se peude acceder al storage desde cualqueir parte del mundo con HTTP o HTTPS peticiones
#
# * Core Storage. For data objects, masive
# * File System service. For cloud
# * Disk Storage for VM. SSD and Hard Divres.
# * Messaging
# * NoSQL storage
# Azure
#
# Blob storage. For binaty or text. Imaegs , video, audio..
# Para usarlo:
# 1. Crear cuenta en Azure Storage mediante Azure Portal, POwerShell o CLI.
#
# ### 3.2 Aspectos básicos de Disk Storage
# Para virtual manchines.
# Hay SSD, HDD y Ultra disk (uso intensivo como SAP y HANA, trasnacciones)
# Son IaaS con error 0%
#
# ### 3.3 Aspectos básicos de Azure Blob Storage
# No estructurado de bianrios o texto. Para video, datos cientificos... etc.
# Azure se ecnarga del almacenamiento (no como los discos). Se almacenan en contenedores.
#
# Usarlo para:
# * Ver imágenes o documentos directamente en un explorador.
# * Almacenamiento de archivos para acceso distribuido.
# * Streaming de audio y vídeo.
# * Copias  de seguridad y restauración, recuperación ante desastres y archivado.
# * Almacenamiento de datos para el análisis en local o en un servicio hospedado de Azure.
# * Almacenamiento de hasta 8 TB de datos para máquinas virtuales.
#
# ### 3.4 Aspectos básicos de Azure Files
#
# Recursos comaprtidos que puende ser acccedidos desde cualquer parte del mundo mediante url  o token de firma de aacceso compartido (SAS)
# Usarlo paara:
# * Archivos comaprtidos accedidos desde maquinas virtuales
# * recursos locales
#
#
# ### 3.5 Descripción de los niveles de acceso de blobs
# diferentes niveles de acceso para el almacenamiento de blobs
# * **Nivel de acceso frecuente:** Datos accesidos con freuencia( Ej: imágenes para el sitio web).
# * **Nivel de acceso esporádico:** optimizado para datos a los que se accede con poca frecuencia y que se almacenan al menos durante 30 días (por ejemplo, las facturas de los clientes).
# * **Nivel de acceso de archivo:** conveniente para datos a los que raramente se accede y que se almacenan durante al menos 180 días con requisitos de latencia flexibles (por ejemplo, copias de seguridad a largo plazo).
#
# Las siguientes consideraciones se aplican a los distintos niveles de acceso:
#
# * Solo los niveles de acceso frecuente y esporádico se pueden establecer en el nivel de cuenta.
# * El nivel de acceso de archivo no está disponible en el nivel de cuenta.
# * Los niveles frecuente, esporádico y de archivo se pueden establecer en el nivel de blob durante la carga o después de esta.
# * Los datos del nivel de acceso esporádico pueden tolerar una disponibilidad ligeramente inferior, pero aun así requieren una gran durabilidad, una latencia de recuperación y unas características de rendimiento similares a las de los datos de acceso frecuente. En el caso de los datos de acceso esporádico, un contrato de nivel de servicio (SLA) con una disponibilidad ligeramente inferior y unos costos de acceso mayores, en comparación con los datos de acceso frecuente, es aceptable a cambio de unos costos de almacenamiento menores.
# * El almacenamiento de archivo almacena datos sin conexión y ofrece los menores costos de almacenamiento, pero los mayores costos de acceso y rehidratación de datos.
#
# ### 3.6 Prueba de conocmiento
# 1. ¿Cuál es el primer paso que se debe llevar a cabo para compartir un archivo de imagen como blob en Azure Storage?**Cree una cuenta de Azure Storage.**
# 2. ¿Qué opción de Azure Storage es mejor para almacenar datos para copias de seguridad y restauración, recuperación ante desastres y archivado?**Azure Blob Storage**
